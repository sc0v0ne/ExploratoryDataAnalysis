# %% [markdown]
# <a href="https://www.kaggle.com/code/sc0v1n0/eda-my-strava-activities?scriptVersionId=189103634" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

pd.set_option('display.max_columns', 500)

# %% [markdown]
# # EDA

# %%
data_path = os.path.join('/kaggle/input/my-strava-activities', '/kaggle/input/my-strava-activities/my_activites.csv')

ds = pd.read_csv(data_path)
ds.shape
# Out:
# (1236, 83)

# %%
ds
# Out:
#                Data da atividade   Nome da atividade Tipo de atividade  \
# 0     26 de ago de 2018 10:21:09  Árvore da fantasia          Pedalada
# 1     23 de set de 2018 10:23:39            Estradão          Pedalada
# 2     24 de set de 2018 19:46:53      Afternoon Ride          Pedalada
# 3     25 de set de 2018 19:48:56      Afternoon Ride          Pedalada
# 4     26 de set de 2018 09:11:14        Morning Ride          Pedalada
# ...                          ...                 ...               ...
# 1231  29 de fev de 2024 09:44:35    Walked dogs 🐶🐶🐶🐕         Caminhada
# 1232   4 de mar de 2024 09:16:54         Morning Run           Corrida
# 1233   4 de mar de 2024 09:35:52     Walked dogs 🐶🐶🐶         Caminhada
# 1234   3 de mar de 2024 09:36:23     Walked dogs 🐶🐶🐕         Caminhada
# 1235   2 de mar de 2024 09:37:09    Walked dogs 🐶🐶🐶🐕         Caminhada
#
#      Descrição da atividade  Tempo decorrido Distância  \
# 0                       NaN            13897      40,8
# ...

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1236 entries, 0 to 1235
# Data columns (total 83 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Data da atividade                   1236 non-null   object
#  1   Nome da atividade                   1234 non-null   object
#  2   Tipo de atividade                   1236 non-null   object
#  3   Descrição da atividade              3 non-null      object
#  4   Tempo decorrido                     1236 non-null   int64
#  5   Distância                           1236 non-null   object
#  6   Frequência cardíaca máxima          2 non-null      float64
#  7   Esforço relativo                    2 non-null      float64
#  8   Deslocamento                        1236 non-null   bool
#  9   Observação privada da atividade     0 non-null      float64
#  10  Equipamento da atividade            1084 non-null   object
# ...

# %%
ds.describe()
# Out:
#        Tempo decorrido  Frequência cardíaca máxima  Esforço relativo  \
# count     1.236000e+03                     2.00000               2.0
# mean      1.739981e+06                   114.50000               2.0
# std       6.108297e+07                     2.12132               0.0
# min       1.000000e+00                   113.00000               2.0
# 25%       1.503000e+03                   113.75000               2.0
# 50%       1.753000e+03                   114.50000               2.0
# 75%       2.288750e+03                   115.25000               2.0
# max       2.147484e+09                   116.00000               2.0
#
#        Observação privada da atividade  Peso do atleta  Peso da bicicleta  \
# count                              0.0      166.000000         360.000000
# mean                               NaN       84.120482          16.052778
# std                                NaN        1.438834           0.223901
# ...

# %%
ds.isna().sum()
# Out:
# Data da atividade                        0
# Nome da atividade                        2
# Tipo de atividade                        0
# Descrição da atividade                1233
# Tempo decorrido                          0
#                                       ...
# Distância recém-explorada             1236
# Distância de terra recém-explorada    1236
# Contagem de atividades                1236
# Total de passos                       1219
# Economia de carbono                   1236
# Length: 83, dtype: int64

# %%
ds.columns
# Out:
# Index(['Data da atividade', 'Nome da atividade', 'Tipo de atividade',
#        'Descrição da atividade', 'Tempo decorrido', 'Distância',
#        'Frequência cardíaca máxima', 'Esforço relativo', 'Deslocamento',
#        'Observação privada da atividade', 'Equipamento da atividade',
#        'Peso do atleta', 'Peso da bicicleta', 'Tempo decorrido.1',
#        'Tempo de movimentação', 'Distância.1', 'Velocidade máx.',
#        'Velocidade média', 'Ganho de elevação', 'Perda de elevação',
#        'Elevação mínima', 'Elevação máxima', 'Inclinação máxima',
#        'Inclinação média', 'Inclinação positiva média',
#        'Inclinação negativa média', 'Cadência máxima', 'Cadência média',
#        'Frequência cardíaca máxima.1', 'Frequência cardíaca média',
#        'Máximo de watts', 'Média de watts', 'Calorias', 'Temperatura máxima',
#        'Temperatura média', 'Esforço relativo.1', 'Total de trabalho',
#        'Número de corridas', 'Tempo de subida', 'Tempo de descida',
# ...
